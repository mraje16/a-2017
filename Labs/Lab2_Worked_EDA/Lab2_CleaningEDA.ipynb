# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A
#
# ## Lab 2: Cleaning and EDA of Goodreads
#
# **Harvard University**<br>
# **Fall 2017**<br>
# **Instructors: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine**
#
# ---

# %% [markdown]
# # Table of Contents
# <ol start="0">
# <li> Learning Goals </li>
# <li> Loading and Cleaning with Pandas</li>
# <li> Asking Questions?  </li>
# <li> Parsing and Completing the Dataframe  </li>
# <li> EDA  </li>
# <li> Determining the Best Books  </li>
# <li>Trends in Popularity of Genres </li>
# </ol>

# %% [markdown]
# ## Learning Goals
#
# About 6000 odd "best books" were fetched and parsed from [Goodreads](https://www.goodreads.com). The "bestness" of these books came from a proprietary formula used by Goodreads and published as a list on their web site.
#
# We parsed the page for each book and saved data from all these pages in a tabular format as a CSV file. In this lab we'll clean and further parse the data.  We'll then do some exploratory data analysis to answer questions about these best books and popular genres.
#
#
# By the end of this lab, you should be able to:
#
# - Load and systematically address missing values, ancoded as `NaN` values in our data set, for example, by removing observations associated with these values.
# - Parse columns in the dataframe to create new dataframe columns.
# - Create and interpret visualizations to explore the data set
#
# *This lab corresponds to lectures 2 and 3 and maps on to homework 1 and further.*

# %% [markdown]
# ### Basic EDA workflow
#
# (From the lecture, repeated here for convenience).
#
# The basic workflow is as follows:
#
# 1. **Scrape**  data using beautiful soup and python request.
# 2. **Build** a DataFrame from the data (ideally, put all data in this object)
# 3. **Clean** the DataFrame. It should have the following properties:
#     - Each row describes a single object
#     - Each column describes a property of that object
#     - Columns are numeric whenever appropriate
#     - Columns contain atomic properties that cannot be further decomposed
# 4. Explore **global properties**. Use histograms, scatter plots, and aggregation functions to summarize the data.
# 5. Explore **group properties**. Use groupby and small multiples to compare subsets of the data.
#
# This process transforms your data into a format which is easier to work with, gives you a basic overview of the data's properties, and likely generates several questions for you to followup in subsequent analysis.

# %% [markdown]
# ## Part 1: Loading and Cleaning with Pandas
# Read in the `goodreads.csv` file, examine the data, and do any necessary data cleaning.
#
# Here is a description of the columns (in order) present in this csv file:
#
# ```
# rating: the average rating on a 1-5 scale achieved by the book
# review_count: the number of Goodreads users who reviewed this book
# isbn: the ISBN code for the book
# booktype: an internal Goodreads identifier for the book
# author_url: the Goodreads (relative) URL for the author of the book
# year: the year the book was published
# genre_urls: a string with '|' separated relative URLS of Goodreads genre pages
# dir: a directory identifier internal to the scraping code
# rating_count: the number of ratings for this book (this is different from the number of reviews)
# name: the name of the book
# ```
#
# Report all the issues you found with the data and how you resolved them.
#
# [15 minutes]
#
# ----

# %%
import pandas as pd

col_names = ['rating', 'review_count', 'isbn', 'booktype', 'author_url', 'year', 'genre_urls', 'dir', 'rating_count', 'name']
df = pd.read_csv('data/goodreads.csv', header = None, names = col_names)

df.head()
# Out:
#    rating review_count        isbn         booktype  \
# 0    4.40       136455  0439023483  good_reads:book
# 1    4.41        16648  0439358078  good_reads:book
# 2    3.56        85746  0316015849  good_reads:book
# 3    4.23        47906  0061120081  good_reads:book
# 4    4.23        34772  0679783261  good_reads:book
#
#                                           author_url    year  \
# 0  https://www.goodreads.com/author/show/153394.S...  2008.0
# 1  https://www.goodreads.com/author/show/1077326....  2003.0
# 2  https://www.goodreads.com/author/show/941441.S...  2005.0
# 3  https://www.goodreads.com/author/show/1825.Har...  1960.0
# 4  https://www.goodreads.com/author/show/1265.Jan...  1813.0
#
#                                           genre_urls  \
# 0  /genres/young-adult|/genres/science-fiction|/g...
# 1  /genres/fantasy|/genres/young-adult|/genres/fi...
# 2  /genres/young-adult|/genres/fantasy|/genres/ro...
# 3  /genres/classics|/genres/fiction|/genres/histo...
# 4  /genres/classics|/genres/fiction|/genres/roman...
#
#                                                  dir rating_count  \
# 0                dir01/2767052-the-hunger-games.html      2958974
# 1  dir01/2.Harry_Potter_and_the_Order_of_the_Phoe...      1284478
# 2                          dir01/41865.Twilight.html      2579564
# 3              dir01/2657.To_Kill_a_Mockingbird.html      2078123
# 4                dir01/1885.Pride_and_Prejudice.html      1388992
#
#                                                 name
# 0            The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2                            Twilight (Twilight, #1)
# 3                              To Kill a Mockingbird
# 4                                Pride and Prejudice

# %%
#Cleaning the data

#1. Setting header as column names
#2. review_count is object type => some values are null => .astype(int) will not work => drop these rows
#3. Change into empty strings

print(df.dtypes)

df[df['isbn'].isnull()]
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object
#       rating review_count isbn         booktype  \
# 16      3.92        38061  NaN  good_reads:book
# 49      3.85        11628  NaN  good_reads:book
# 85      4.16        14968  NaN  good_reads:book
# 116     3.92         8393  NaN  good_reads:book
# 156     4.03         3473  NaN  good_reads:book
# 195     4.06         8630  NaN  good_reads:book
# 299     4.20        19915  NaN  good_reads:book
# 301     4.37         2058  NaN  good_reads:book
# 308     3.73         3801  NaN  good_reads:book
# 444     3.79         2291  NaN  good_reads:book
# 529     4.25        14968  NaN  good_reads:book
# 561     3.90         1686  NaN  good_reads:book
# 592     4.33         9619  NaN  good_reads:book
# 610     4.09         2528  NaN  good_reads:book
# 648     4.13         7988  NaN  good_reads:book
# 656     4.13         2023  NaN  good_reads:book
# 686     4.22         7908  NaN  good_reads:book
# 703     4.15         2919  NaN  good_reads:book
# 716     3.98         3177  NaN  good_reads:book
# 736     4.21        15995  NaN  good_reads:book
# 824     4.45         5802  NaN  good_reads:book
# 837     4.16         4040  NaN  good_reads:book
# 869     4.35         5948  NaN  good_reads:book
# 939     4.33           31  NaN  good_reads:book
# 974     4.46           60  NaN  good_reads:book
# 1006    4.28         6357  NaN  good_reads:book
# 1007    4.29         6221  NaN  good_reads:book
# 1038    4.03         4253  NaN  good_reads:book
# 1055    4.00         1691  NaN  good_reads:book
# 1072    4.18           47  NaN  good_reads:book
# ...      ...          ...  ...              ...
# 5728    4.20           25  NaN  good_reads:book
# 5729    4.83           16  NaN  good_reads:book
# 5730    4.14           78  NaN  good_reads:book
# 837   /genres/fantasy|/genres/young-adult|/genres/ad...
# 869   /genres/romance|/genres/new-adult|/genres/youn...
# 939   /genres/fantasy|/genres/fantasy|/genres/parano...
# 974   /genres/fantasy|/genres/young-adult|/genres/ad...
# 1006  /genres/new-adult|/genres/romance|/genres/cont...
# 1007  /genres/romance|/genres/romance|/genres/contem...
# 1038  /genres/young-adult|/genres/fantasy|/genres/pa...
# 1055  /genres/fiction|/genres/thriller|/genres/spy-t...
# 1072  /genres/history|/genres/non-fiction|/genres/wa...
# ...                                                 ...
# 5728                                  /genres/childrens
# 5729                                                NaN
# 5730  /genres/romance|/genres/new-adult|/genres/roma...
# 5754  /genres/romance|/genres/romance|/genres/interr...
# 5756  /genres/romance|/genres/new-adult|/genres/roma...
# 5760  /genres/young-adult|/genres/romance|/genres/my...
# 5762  /genres/fantasy|/genres/childrens|/genres/midd...
# 5764  /genres/non-fiction|/genres/self-help|/genres/...
# 5778                                                NaN
# 5790  /genres/young-adult|/genres/romance|/genres/co...
# 5817                                /genres/non-fiction
# 5821  /genres/religion|/genres/biography|/genres/his...
# 5823                /genres/young-adult|/genres/romance
# 5825  /genres/young-adult|/genres/romance|/genres/my...
# 5847  /genres/historical-fiction|/genres/fiction|/ge...
# 5858  /genres/novels|/genres/romantic|/genres/litera...
# 5859                    /genres/fiction|/genres/fantasy
# 5866  /genres/romance|/genres/asian-literature|/genr...
# 5872  /genres/romance|/genres/new-adult|/genres/cont...
# 5880  /genres/romance|/genres/m-m-romance|/genres/sc...
# 5882  /genres/romance|/genres/romance|/genres/contem...
# 5900  /genres/romance|/genres/asian-literature|/genr...
# 5942  /genres/science-fiction|/genres/classics|/genr...
# 5944  /genres/novels|/genres/fiction|/genres/asian-l...
# 5964  /genres/science-fiction|/genres/fiction|/genre...
# 5972  /genres/romance|/genres/romance|/genres/contem...
# 5976  /genres/romance|/genres/science-fiction|/genre...
# 5977  /genres/fiction|/genres/novels|/genres/literat...
# 5991  /genres/novels|/genres/fiction|/genres/religio...
# 5998  /genres/religion|/genres/islam|/genres/religio...
#
#                                                     dir rating_count  \
# 16         dir01/18619684-the-time-traveler-s-wife.html       927254
# 49                               dir01/7604.Lolita.html       374886
# 85                  dir01/18660669-vampire-academy.html       297022
# 116                       dir02/49552.The_Stranger.html       307566
# 156                dir02/7190.The_Three_Musketeers.html       156968
# 195                     dir02/4502877-midnight-sun.html       124018
# 299              dir03/11505797-beautiful-disaster.html       271613
# 301                         dir04/646462.The_Quran.html        29243
# 308                     dir04/77013.As_I_Lay_Dying.html        76262
# 444                  dir05/17716.Waiting_for_Godot.html        75494
# 529            dir06/10664113-a-dance-with-dragons.html       239921
# 561          dir06/3388.Captain_Corelli_s_Mandolin.html        47679
# 592                         dir06/13372690-slammed.html       108997
# 610   dir07/374233.If_on_a_Winter_s_Night_a_Traveler...        34768
# 648     dir07/11408650-the-unbecoming-of-mara-dyer.html        63906
# 656                           dir07/32423.Watchers.html        87516
# 686                       dir07/11500217-angelfall.html        63175
# 824                              The Sea of Tranquility
# 837       The Ruins of Gorlan (Ranger's Apprentice, #1)
# 869                      Point of Retreat (Slammed, #2)
# 939          Nobody Loves a Bigfoot Like a Bigfoot Babe
# 974                 Switch! The Lost Kingdoms of Karibu
# 1006                       Fallen Too Far (Too Far, #1)
# 1007            On Dublin Street (On Dublin Street, #1)
# 1038                               Rapture (Fallen, #4)
# 1055                  The Spy Who Came In from the Cold
# 1072                          Sliding on the Snow Stone
# ...                                                 ...
# 5728                                  Where Is My Home?
# 5729                        The Keeper (The Keeper, #5)
# 5730          Tainted Bodies (Photographer Trilogy, #1)
# 5754                                              Beast
# 5756                                Pulse (Collide, #2)
# 5760            Friends vs. Family (The Ghost Bird, #3)
# 5762                    Alice Will (Dreams of Chaos #1)
# 5764                                     Staying Strong
# 5778                                        (Un) Spoken
# 5790                 Introductions (The Ghost Bird, #1)
# 5817                                          28 Ø­Ø±Ù
# 5821                                Ø¹Ø¨ÙØ±ÙØ© Ø¹Ù
# Ø±
# 5823  No sonrÃ­as, que me enamoro (El club de los in...
# 5825                    First Days (The Ghost Bird, #2)
# 5847                                          Penmarric
# 5858                                         ÙÙØ¨ØªØ§
# 5859                                               Gone
# 5866                                    Winter in Tokyo
# 5872                        That Wedding (That Boy, #2)
# 5880     The Interludes (In the company of shadows, #3)
# 5882                       Forever with You (Fixed, #3)
# 5900                               Sunshine Becomes You
# 5942               The Complete Works of H.P. Lovecraft
# 5944                                Negeri Para Bedebah
# 5964                                  Battlefield Earth
# 5972                Perfection (Neighbor from Hell, #2)
# 5976                                      Transcendence
# 5977                                         Ø§ÙØªÙÙ
# 5991                                Ø£ÙÙØ§Ø­ ÙØ¯Ø³Ø±
# 5998              Ø£Ø³Ø¹Ø¯ Ø§Ù
# Ø±Ø£Ø© ÙÙ Ø§ÙØ¹Ø§ÙÙ
#
#
# [475 rows x 10 columns]

# %% [markdown]
# ##   Part 2: Asking Questions
# Think of few questions we want to ask and then examine the data and decide if the dataframe contains what you need to address these questions.
#
# [5 min]
#
# ---

# %% [markdown]
# ##  Part 3: Parsing and Completing the Data Frame
#
# We will need author and genre to proceed! Parse the `author` column from the author_url and `genres` column from the genre_urls. Keep the `genres` column as a string separated by '|'.
#
# Hint: Use panda's `map` to assign new columns to the dataframe.
#
# [10 minutes]
#
# ---

# %% [markdown]
# ## Part 4: EDA
# Before proceeding any further, get to know the dataset using a few "global property" visualizations, illustrating histograms with both linear and log scales. Do you find anything interesting or strange?
#
#
# [10 minutes]
#
# ---

# %% [markdown]
# ## Part 5:  Determining the Best Books
#
# This is an example of an analysis of the "grouped property" type.
#
# Think of some reasonable definitions of what it could mean to be a "best book." (After all, these are all the best books according to Goodreads)
#
# [5 minutes]
#
# ---

# %% [markdown]
# ## Part 6:  Trends in Popularity of Genres
#
# This is an example of an analysis of the "grouped property" type.
#
# There are a lot of questions you could ask about genres.
# * Which genre is currently the most popular?
# * Better, based on our data, what draw conclusions can you draw about the time evolution of the popularity of each genre?
#
# [15 minutes]
#
# ---

# %% [markdown]
# ### Part 6.1: What can you conclude from the above visualizations?
# Pick two or three genres and describe how the popularity of these genres fluctuates with time.
